# %%
# !pip install nltk
# Out:
# ...
# WARNING: There was an error checking the latest version of pip.

# %%
import nltk
nltk.download()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# True

# %%
nltk.corpus.gutenberg.fileids()
# Out:
# ['austen-emma.txt',
#  'austen-persuasion.txt',
#  'austen-sense.txt',
#  'bible-kjv.txt',
#  'blake-poems.txt',
#  'bryant-stories.txt',
#  'burgess-busterbrown.txt',
#  'carroll-alice.txt',
#  'chesterton-ball.txt',
#  'chesterton-brown.txt',
#  'chesterton-thursday.txt',
#  'edgeworth-parents.txt',
#  'melville-moby_dick.txt',
#  'milton-paradise.txt',
#  'shakespeare-caesar.txt',
#  'shakespeare-hamlet.txt',
#  'shakespeare-macbeth.txt',
#  'whitman-leaves.txt']

# %%
moby_dick = nltk.corpus.gutenberg.words('melville-moby_dick.txt')

# %%
len(moby_dick)
# Out:
# 260819

# %%
nltk.Text(nltk.corpus.gutenberg.words('melville-moby_dick.txt')).concordance("surprise")
# Out:
# Displaying 10 of 10 matches:
# I came nigh singing out with fresh surprise . There was no hair on his head --
# ies about whaling ; to my no small surprise , nearly every man maintained a pr
# r plans for the morrow . But to my surprise and no small concern , Queequeg no
# nife , old Bildad , to my no small surprise , considering that he was such an
# ith even more intense interest and surprise than the rest , and at the mention
# yeing his superior with increasing surprise , but at last seemed struck with a
# live ; it cannot be much matter of surprise that some whalemen should go still
# ht alongside and beheaded , to the surprise of all , the announcement was made
# ical tail ; none of these would so surprise you , as half a glimpse of that un
# hen some expressed their delighted surprise , he , in substance , said , that

# %%
from nltk.corpus import gutenberg

for fileid in gutenberg.fileids():
    num_chars = len(gutenberg.raw(fileid))
    num_words = len(gutenberg.words(fileid))
    num_sents = len(gutenberg.sents(fileid))
    num_vocab = len(set([w.lower() for w in gutenberg.words(fileid)]))
    print(int(num_chars/num_words), int(num_words/num_sents), int(num_words/num_vocab), fileid)
# Out:
# 4 24 26 austen-emma.txt
# 4 26 16 austen-persuasion.txt
# 4 28 22 austen-sense.txt
# 4 33 79 bible-kjv.txt
# 4 19 5 blake-poems.txt
# 4 19 14 bryant-stories.txt
# 4 17 12 burgess-busterbrown.txt
# 4 20 12 carroll-alice.txt
# 4 20 11 chesterton-ball.txt
# 4 22 11 chesterton-brown.txt
# 4 18 10 chesterton-thursday.txt
# 4 20 24 edgeworth-parents.txt
# 4 25 15 melville-moby_dick.txt
# 4 52 10 milton-paradise.txt
# 4 11 8 shakespeare-caesar.txt
# 4 12 7 shakespeare-hamlet.txt
# 4 12 6 shakespeare-macbeth.txt
# 4 36 12 whitman-leaves.txt

# %%
macbeth_sentences = gutenberg.sents('shakespeare-macbeth.txt')
macbeth_sentences[17]
# Out:
# ['There', 'to', 'meet', 'with', 'Macbeth']

# %%
from nltk.corpus import webtext
webtext.fileids()
# Out:
# ['firefox.txt',
#  'grail.txt',
#  'overheard.txt',
#  'pirates.txt',
#  'singles.txt',
#  'wine.txt']

# %%
nltk.corpus.webtext.sents('grail.txt')[101:105]
# Out:
# [['CUSTOMER',
#   ':',
#   'You',
#   "'",
#   're',
#   'not',
#   'fooling',
#   'anyone',
#   'you',
#   'know',
#   '.'],
#  ['Look', ',', 'isn', "'", 't', 'there', 'something', 'you', 'can', 'do', '?'],
#  ['DEAD', 'PERSON', ':', '[', 'singing', ']', 'I', 'feel', 'happy', '...'],
#  ['I', 'feel', 'happy', '.']]

# %%
from nltk.corpus import brown
news_txt = brown.words(categories='news')
mystery_txt = brown.words(categories='mystery')
news_dist = nltk.FreqDist([w.lower() for w in news_txt])
mystery_dist = nltk.FreqDist([w.lower() for w in mystery_txt ])
modals =['can' , 'could', 'may', 'might', 'must', 'will']
for m in modals:
    print(m + ": ", news_dist[m] , ' ' , mystery_dist[m])
# Out:
# can:  94   45
# could:  87   145
# may:  93   15
# might:  38   57
# must:  53   31
# will:  389   25

# %%
from ebooklib import epub
import ebooklib
import os
import nltk
epub_file_celine = []
book = epub.read_epub('./celine-louis-ferdinand-london-bridge-2017.epub')

# %%
for doc in book.get_items():
    doc_content = str(doc.content)
    for w in nltk.word_tokenize(doc_content):
        epub_file_celine.append(w.lower())

# %%
epub_file_celine[11000:11200]
# Out:
# ['give',
#  'sosth\\xc3\\xa8ne',
#  'a',
#  'piece',
#  'of',
#  'my',
#  'mind',
#  '.',
#  'i',
#  'was',
#  'going',
#  'to',
#  'set',
#  'him',
#  'straight.',
#  '<',
#  '/p',
#  '>',
#  '\\r\\n\\t\\t\\t',
#  '<',
#  'p',
#  'class=',
#  "''",
#  'body',
#  "''",
#  '>',
#  '\\xe2\\x80\\x9csosth\\xc3\\xa8ne',
#  '!',
#  'sosth\\xc3\\xa8ne',
#  '!',
#  '\\xe2\\x80\\x9d',
#  'i',
#  'grabbed',
#  'him\\xe2\\x80\\xa6',
#  '\\xe2\\x80\\x9csosth\\xc3\\xa8ne',
#  '!',
#  'how',
#  'much',
#  'longer',
#  'is',
#  'this',
#  'going',
#  'to',
#  'go',
#  'on',
#  '?',
#  'could',
#  'you',
#  'please',
#  'tell',
#  'me',
#  ',',
#  'huh',
#  '?',
#  'do',
#  'you',
#  'have',
#  'any',
#  'idea',
#  ',',
#  'dear',
#  'sir',
#  '?',
#  'because',
#  'you',
#  'can',
#  'count',
#  'me',
#  'out',
#  '!',
#  '\\xe2\\x80\\xa6',
#  'no',
#  'way',
#  'i\\xe2\\x80\\x99m',
#  'going',
#  'back',
#  'to',
#  'the',
#  'war',
#  '!',
#  '\\xe2\\x80\\xa6',
#  'just',
#  'forget',
#  'it',
# ...

# %%
genre_word = [(genre, word)
              for genre in ['news', 'romance']
              for word in brown.words(categories=genre)]
len(genre_word)
# Out:
# 170576

# %%
genre_word[1] , genre_word[2]
# Out:
# (('news', 'Fulton'), ('news', 'County'))

# %%
n=0
for tuple in genre_word:
    if genre_word[i]['romance']:
        print (tuple)
# Out:
# 100555 ('romance', 'They')
# 100556 ('romance', 'neither')
# 100557 ('romance', 'liked')
# 100558 ('romance', 'nor')
# 100559 ('romance', 'disliked')
# 100560 ('romance', 'the')
# 100561 ('romance', 'Old')
# 100562 ('romance', 'Man')
# 100563 ('romance', '.')
# 100564 ('romance', 'To')
# 100565 ('romance', 'them')
# 100566 ('romance', 'he')
# 100567 ('romance', 'could')
# 100568 ('romance', 'have')
# 100569 ('romance', 'been')
# 100570 ('romance', 'the')
# 100571 ('romance', 'broken')
# 100572 ('romance', 'bell')
# 100573 ('romance', 'in')
# 100574 ('romance', 'the')
# 100575 ('romance', 'church')
# 100576 ('romance', 'tower')
# 100577 ('romance', 'which')
# 100578 ('romance', 'rang')
# 100579 ('romance', 'before')
# 100580 ('romance', 'and')
# 100581 ('romance', 'after')
# 100582 ('romance', 'Mass')
# 100583 ('romance', ',')
# 100584 ('romance', 'and')
# 100585 ('romance', 'at')
# 100586 ('romance', 'noon')
# 100587 ('romance', ',')
# 100588 ('romance', 'and')
# ...

# %%
import numpy as np
array = np.array(genre_word)[:,0] == 'romance'
np.array(genre_word)[array,1]
# Out:
# array(['They', 'neither', 'liked', ..., 'not', "''", '.'], dtype='<U29')

# %%
genre_word = [(genre ,word)
               for genre in ['news','romance']
               for word in brown.words(categories=genre)]

# %%
cfd = nltk.ConditionalFreqDist(genre_word)

# %%
cfd.conditions()
# Out:
# ['news', 'romance']

# %%
type(cfd)
# Out:
# nltk.probability.ConditionalFreqDist

# %% [markdown]
# plotting and tabulating the distribustions

# %%
from nltk.corpus import inaugural
cfd = nltk.ConditionalFreqDist(
        (target, fileid[:4])
        for fileid in inaugural.fileids()
        for w in inaugural.words(fileid)
        for target in ['america', 'citizen']
        if w.lower().startswith(target))

# %%
days = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']

# %%
genre_word = nltk.ConditionalFreqDist([(genre, word)
              for genre in ['news', 'romance']
              for word in brown.words(categories=genre)])

# %%
genre_word.tabulate(conditions = ['news', 'romance'] , samples = days )
# Out:
#            Monday   Tuesday Wednesday  Thursday    Friday  Saturday    Sunday
#    news        54        43        22        20        41        33        51
# romance         2         3         3         1         3         4         5

# %% [markdown]
# senses and synonyms

# %%
from nltk.corpus import wordnet as wn
wn.synsets('dish')
# Out:
# [Synset('dish.n.01'),
#  Synset('dish.n.02'),
#  Synset('dish.n.03'),
#  Synset('smasher.n.02'),
#  Synset('dish.n.05'),
#  Synset('cup_of_tea.n.01'),
#  Synset('serve.v.06'),
#  Synset('dish.v.02')]

# %%
for synset in wn.synsets('dish'):
    print(wn.lemma(synset))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [9], in <cell line: 1>()
#       1 for synset in wn.synsets('dish'):
# ----> 2     print(wn.lemma(synset))
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\nltk\corpus\reader\wordnet.py:1395, in WordNetCorpusReader.lemma(self, name, lang)
#    1392 """Return lemma object that matches the name"""
#    1393 # cannot simply split on first '.',
#    1394 # e.g.: '.45_caliber.a.01..45_caliber'
# -> 1395 separator = SENSENUM_RE.search(name).end()
#    1397 synset_name, lemma_name = name[: separator - 1], name[separator:]
#    1399 synset = self.synset(synset_name)
#
# TypeError: expected string or bytes-like object

# %%
wn.synsets('dish')
# Out:
# [Synset('dish.n.01'),
#  Synset('dish.n.02'),
#  Synset('dish.n.03'),
#  Synset('smasher.n.02'),
#  Synset('dish.n.05'),
#  Synset('cup_of_tea.n.01'),
#  Synset('serve.v.06'),
#  Synset('dish.v.02')]

# %%
wn.synset('right_whale.n.01')
# Out:
# Synset('right_whale.n.01')

# %%
from nltk.corpus import wordnet as wn

# %%
wn.synset('car.n.01').lemma_names
# Out:
# "<bound method Synset.lemma_names of Synset('car.n.01')>"

# %%
motorcar = wn.synset('car.n.01')
types_of_motorcar = motorcar.hyponyms()

sorted([lemma.name for synset in types_of_motorcar for lemma in synset.lemmas])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [8], in <cell line: 4>()
#       1 motorcar = wn.synset('car.n.01')
#       2 types_of_motorcar = motorcar.hyponyms()
# ----> 4 sorted([lemma.name for synset in types_of_motorcar for lemma in synset.lemmas])
#
# Input In [8], in <listcomp>(.0)
#       1 motorcar = wn.synset('car.n.01')
#       2 types_of_motorcar = motorcar.hyponyms()
# ----> 4 sorted([lemma.name for synset in types_of_motorcar for lemma in synset.lemmas])
#
# TypeError: 'method' object is not iterable

# %%
print(wn.synset('car.n.01').lemma_names.name())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [12], in <cell line: 1>()
# ----> 1 print(wn.synset('car.n.01').lemma_names.name())
#
# AttributeError: 'function' object has no attribute 'name'

# %%
import  nltk

# %%
raw = 'Red lorry, yellow lorry, red lorry, yellow lorry.'
text = nltk.word_tokenize(raw)
fdist = nltk.FreqDist(text)
list(fdist)
# Out:
# ['lorry', ',', 'yellow', 'Red', 'red', '.']

# %%
dir(fdist)
# Out:
# ['B',
#  'N',
#  'Nr',
#  '_N',
#  '__add__',
#  '__and__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__init__',
#  '__init_subclass__',
#  '__ior__',
#  '__isub__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__missing__',
#  '__module__',
#  '__ne__',
#  '__neg__',
#  '__new__',
#  '__or__',
#  '__pos__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__ror__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__weakref__',
#  '_cumulative_frequencies',
#  '_keep_positive',
#  'clear',
#  'copy',
#  'elements',
#  'freq',
#  'fromkeys',
#  'get',
#  'hapaxes',
#  'items',
#  'keys',
#  'max',
#  'most_common',
#  'pformat',
#  'plot',
#  'pop',
# ...

# %%
for i in fdist.elements():
    print(i)
# Out:
# Red
# lorry
# lorry
# lorry
# lorry
# ,
# ,
# ,
# yellow
# yellow
# red
# .

# %%
class name:
    def __init__(self, fname, lname):
        self.fname = fname
        self.lname = lname
        self.fullname = fname + ' ' + lname
        self.initial = fname[0] + '.' + lname[0]

# %%
name('ali' , 'ahmed').initial
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [6], in <cell line: 1>()
# ----> 1 name('ali' , 'ahmed').initial()
#
# TypeError: 'str' object is not callable
